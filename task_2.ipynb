# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

headers = requests.utils.default_headers()
headers.update({ 'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/69.0'})

# %%
from bs4 import BeautifulSoup
url = "https://tlgrm.ru/channels"

# %%
req = requests.get(url, headers)
soup = BeautifulSoup(req.content, 'html.parser')
classes = soup.find_all('a',attrs = {'class':'channel-category'})

# %%
chennels_df = pd.DataFrame()

for class_a in classes:
    chennel_df = pd.DataFrame()
    class_name = class_a.text
    href_added = class_a.attrs['data-topic']
    class_url = url+'/'+href_added
    
    
    req = requests.get(class_url, headers)
    soup = BeautifulSoup(req.content, 'html.parser')
    
    chennels = soup.find_all('div',attrs = {'class':'channel-card__info'})[1:]
    chennel_df['hrefs'] = [chennel.a.attrs['href'] for chennel in chennels]
    chennel_df['name'] = [chennel.a.text for chennel in chennels]
    chennel_df['class'] = href_added
    chennels_df = pd.concat([chennels_df,chennel_df], axis = 0)

# %%
chennels_df
# Out:
#                                       hrefs  \
# 0     https://tlgrm.ru/channels/@nexta_live
# 1       https://tlgrm.ru/channels/@nexta_tv
# 2   https://tlgrm.ru/channels/@breakingmash
# 3          https://tlgrm.ru/channels/@topor
# 4      https://tlgrm.ru/channels/@petrovtel
# ..                                      ...
# 10      https://tlgrm.ru/channels/@UzReport
# 11        https://tlgrm.ru/channels/@ShumFM
# 12      https://tlgrm.ru/channels/@zufar123
# 13  https://tlgrm.ru/channels/@gazetauz_ozb
# 14   https://tlgrm.ru/channels/@yangilar_uz
#
#                                     name  class
# 0                             NEXTA Live   news
# 1                                  NEXTA   news
# 2                                   Mash   news
# 3     ТОПОР - Горячие новости | Беларусь   news
# 4                 Крысиное Королевство 🐀   news
# ..                                   ...    ...
# 10                    UzReport.news | РУ  uzbek
# ...

# %%
href_added
# Out:
# 'blogs'

# %%
chennels = soup.find_all('div',attrs = {'class':'channel-card__info'})

# %%
chennel = chennels[-10]

# %%
# Out:
# 'https://tlgrm.ru/channels/@mkbelarus'

# %%
b.a

# %%
[chennel.a.attrs['href'] for chennel in chennels if chennel.a!=None]
# Out:
# []

# %%
chennel = chennels[0]

# %%
# Out:
# 'https://ttttt.me/tg_analytics'

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ru">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="_tgstat_csrk" name="csrf-param"/>
# <meta content="6kcV0gb4XYUzDpDDTemKOIGdRVdYBeaXGMJuYUkJqmG4cEWgf80Z0QBU6qguu_MI7_98Az11p6VvkAIrLXzfNg==" name="csrf-token"/>
# <title>Российские Telegram-каналы. Статистика, аналитика, рейтинг. Telegram Analytics.</title>
# <meta content="https://tgstat.ru/img/big_logo.jpg" property="og:image"/>
# <meta content="Российские Telegram-каналы. Статистика, аналитика, рейтинг. Telegram Analytics." property="twitter:title"/>
# <meta content="@TGStat" property="twitter:site"/>
# <meta content="https://tgstat.ru/img/big_logo.jpg" property="twitter:image"/>
# <meta content="Рейтинг Telegram-каналов. Статистика просмотров, прирост посетителей, контроль репостов и упоминаний канала" name="twitter:description"/>
# ...
