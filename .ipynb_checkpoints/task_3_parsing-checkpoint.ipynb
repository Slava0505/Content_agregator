# %%
import pandas as pd

# %%
chennels_df = pd.read_csv('data/chennels_df.csv')
chennels_df['chennel@'] = chennels_df['hrefs'].apply(lambda x: x[26:])

# %%
from telethon import TelegramClient, events, sync
from telethon.tl.functions.messages import GetHistoryRequest
from telethon.tl.functions.channels import JoinChannelRequest,LeaveChannelRequest

# These example values won't work. You must get your own api_id and
# api_hash from https://my.telegram.org, under API Development.
api_id = 1522790
api_hash = '00008593fd02991e904e01df2abe2310'

client = TelegramClient('session_name', api_id, api_hash)
client.start()

# %%
def parse_n_messages(channel_name, n, client):
    channel = client.get_entity(channel_name)
    posts = client(GetHistoryRequest(
    peer=channel,
    limit=n,
    offset_date=None,
    offset_id=0,
    max_id=0,
    min_id=0,
    add_offset=0,
    hash=0))

    post_texts = [post.message for post in posts.messages]
    chennel_posts_df = pd.DataFrame(zip(post_texts,posts.messages), columns = ['text', 'message'])
    return chennel_posts_df

# %%
posts_df = pd.DataFrame()

# %%
classes = ['business', 'entertainment', 'economics', 'crypto',
       'education', 'music', 'language', 'tech', 'psychology',
       'marketing', 'career',
       'health', 'other']

# %%
chennels_df_to_parse = chennels_df[chennels_df['class'].isin(classes)]
chennels_df_to_parse = chennels_df_to_parse.sample(40)
chennels_df_to_parse = chennels_df_to_parse.sort_values('class')

# %%
chennels_df_to_parse
# Out:
#                                                 hrefs  \
# 237            https://tlgrm.ru/channels/@digitalbiss
# 234              https://tlgrm.ru/channels/@OpenMedia
# 230               https://tlgrm.ru/channels/@busintop
# 220                 https://tlgrm.ru/channels/@Jurist
# 297         https://tlgrm.ru/channels/@brain_drain_ru
# 299         https://tlgrm.ru/channels/@workfreelancer
# 293               https://tlgrm.ru/channels/@castings
# 115  https://tlgrm.ru/channels/@kremlin_mother_expert
# 101      https://tlgrm.ru/channels/@boilerroomchannel
# 117        https://tlgrm.ru/channels/@prezidentgordon
# 165        https://tlgrm.ru/channels/@shkolamishlenia
# 156              https://tlgrm.ru/channels/@lektorium
# 80                  https://tlgrm.ru/channels/@Reddit
# 82                 https://tlgrm.ru/channels/@ru4chan
# 91           https://tlgrm.ru/channels/@retranslyator
# 73                   https://tlgrm.ru/channels/@mudak
# 88             https://tlgrm.ru/channels/@hardchannel
# 474                https://tlgrm.ru/channels/@Medcase
# 459             https://tlgrm.ru/channels/@DoctorViki
# 210          https://tlgrm.ru/channels/@english_yopta
# 211       https://tlgrm.ru/channels/@pesheralingvista
# 206                https://tlgrm.ru/channels/@gramota
# 196          https://tlgrm.ru/channels/@deutschonline
# 203  https://tlgrm.ru/channels/@I_love_english_online
# 213              https://tlgrm.ru/channels/@brokoledu
# 275        https://tlgrm.ru/channels/@postanovich_smm
# 286             https://tlgrm.ru/channels/@epicgrowth
# 168           https://tlgrm.ru/channels/@Music_muzyka
# 185          https://tlgrm.ru/channels/@bassvlog_news
# 190          https://tlgrm.ru/channels/@shams_i_zerin
# 246               https://tlgrm.ru/channels/@iDecency
# 241           https://tlgrm.ru/channels/@PsyEducation
# 259          https://tlgrm.ru/channels/@zen_education
# 240               https://tlgrm.ru/channels/@SilaSlov
# 58             https://tlgrm.ru/channels/@proglibrary
# 69                 https://tlgrm.ru/channels/@addmeto
# 68                  https://tlgrm.ru/channels/@tginfo
# 53                https://tlgrm.ru/channels/@Wylsared
# 65             https://tlgrm.ru/channels/@nuancesprog
# 49                https://tlgrm.ru/channels/@teleblog
#
#                                                 name          class  \
# 237                                   БИЗНЕС DIGITAL       business
# 234                     «Открытые медиа». Эксклюзивы       business
# 230                         Бизнес - Предприниматель       business
# 220                            ЮРИСТ ЕВГЕНИЙ ШУПИКОВ       business
# 297                                      Brain drain         career
# 299                  Фрилансер: вакансии на удаленке         career
# 293                                Кастинги в Москве         career
# 115                             Кремлёвский мамковед      economics
# 101                                        Бойлерная      economics
# 117                                 Президент Гордон      economics
# 165           Школа мышления. Вояж в страну загадок.      education
# 156                                         Лекторий      education
# 80                                            Reddit  entertainment
# 82                                             4chan  entertainment
# 91                                     r/етранслятор  entertainment
# 73                                               MDK  entertainment
# 88                                           Хардкор  entertainment
# 474  International Medical Case Presentation Channel         health
# 459                                          Dr Viki         health
# 210                                    english yopta       language
# 211                                 Пещера лингвиста       language
# 206                       Грамотность (русский язык)       language
# 196                                    Немецкий язык       language
# 203                        Movies & Books in English       language
# 213                     Умный Брокколь | Грамотность       language
# 275                               Один день SMM-щика      marketing
# 286                              Epic Growth Channel      marketing
# 168                   Популярная Музыка | Новинки VK          music
# 185                                    BASSVLOG NEWS          music
# 190                                ЅℋᎯℳЅ_ℐ_ℤℰℛℐℕ ☀️🌙          music
# 246                                     Порядочность     psychology
# 241                                       Психология     psychology
# 259                                             Дзен     psychology
# 240                Саморазвитие | Психология | Книги     psychology
# 58                           Библиотека программиста           tech
# 69                                           addmeto           tech
# 68                                     Telegram Info           tech
# 53                                      Wylsacom Red           tech
# 65                       NOP::Nuances of programming           tech
# 49                                          Телеблог           tech
#
#                    chennel@
# 237            @digitalbiss
# 234              @OpenMedia
# 230               @busintop
# 220                 @Jurist
# 297         @brain_drain_ru
# 299         @workfreelancer
# 293               @castings
# 115  @kremlin_mother_expert
# 101      @boilerroomchannel
# 117        @prezidentgordon
# 165        @shkolamishlenia
# 156              @lektorium
# 80                  @Reddit
# 82                 @ru4chan
# 91           @retranslyator
# 73                   @mudak
# 88             @hardchannel
# 474                @Medcase
# 459             @DoctorViki
# 210          @english_yopta
# 211       @pesheralingvista
# 206                @gramota
# 196          @deutschonline
# 203  @I_love_english_online
# 213              @brokoledu
# 275        @postanovich_smm
# 286             @epicgrowth
# 168           @Music_muzyka
# 185          @bassvlog_news
# 190          @shams_i_zerin
# 246               @iDecency
# 241           @PsyEducation
# 259          @zen_education
# 240               @SilaSlov
# 58             @proglibrary
# 69                 @addmeto
# 68                  @tginfo
# 53                @Wylsared
# 65             @nuancesprog
# 49                @teleblog

# %%
# %%time
for i, (href, name, class_name, channel_name) in chennels_df_to_parse.iloc[:4].iterrows():
    print(i)
    client(JoinChannelRequest(channel_name))
    
    chennel_posts_df = parse_n_messages(channel_name, 500, client)
    chennel_posts_df['class'] = class_name
    chennel_posts_df['channel'] = channel_name

    
    client(LeaveChannelRequest(channel_name))
    
    posts_df = pd.concat([posts_df,chennel_posts_df], axis = 0)
    posts_df.to_csv('data/posts_df.csv', index = False)
# Out:
# 237
# 234
# 230
# 220
# Wall time: 11.5 s

# %%
posts_df
# Out:
#                                                  text  \
# 0   15 МИНУТНОЕ ВИДЕО + PDF\n\n😎 Пять шагов, котор...
# 1   Российский сервис рекомендации врачей и онлайн...
# 2   ​​Оценка текущей ситуации на фондовых рынках\n...
# 3   Эвотор.Маркет и Visa помогают оптимизировать б...
# 4   ​​Сервис Lokalise для переводов сайтов и прило...
# ..                                                ...
# 95  ​​Странные дела происходят в РГСУ\n\nКо мне об...
# 96  Собрал все главные правовые материалы по корон...
# 97  ❗️Режим нерабочих дней продлён до 11 мая включ...
# 98  Продолжаю делиться подборкой актуальных сервис...
# 99  ОТКРЫТИЕ Р/С, РЕГИСТРАЦИЯ БИЗНЕСА\n\nХотя сейч...
#
#                                               message     class  \
# 0   Message(id=189, to_id=PeerChannel(channel_id=1...  business
# 1   Message(id=188, to_id=PeerChannel(channel_id=1...  business
# 2   Message(id=187, to_id=PeerChannel(channel_id=1...  business
# 3   Message(id=185, to_id=PeerChannel(channel_id=1...  business
# 4   Message(id=183, to_id=PeerChannel(channel_id=1...  business
# ..                                                ...       ...
# 95  Message(id=962, to_id=PeerChannel(channel_id=1...  business
# 96  Message(id=961, to_id=PeerChannel(channel_id=1...  business
# 97  Message(id=960, to_id=PeerChannel(channel_id=1...  business
# 98  Message(id=958, to_id=PeerChannel(channel_id=1...  business
# 99  Message(id=957, to_id=PeerChannel(channel_id=1...  business
#
#            channel
# 0   @cashroyal_biz
# 1   @cashroyal_biz
# 2   @cashroyal_biz
# 3   @cashroyal_biz
# 4   @cashroyal_biz
# ..             ...
# 95         @Jurist
# 96         @Jurist
# 97         @Jurist
# 98         @Jurist
# 99         @Jurist
#
# [5358 rows x 4 columns]

# %%
posts_df.to_csv('data/posts_df.csv', index = False)

# %%
posts_df
