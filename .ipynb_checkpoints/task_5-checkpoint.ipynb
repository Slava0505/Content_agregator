# %%
import pandas as pd
import numpy as np

import stop_words
import nltk
from nltk.stem import  SnowballStemmer
from nltk import word_tokenize
from nltk.corpus import stopwords
stop_ru = set(stopwords.words('russian'))
stop =  stop_ru | set(stop_words.get_stop_words('ru')) -set('год')

stemmer_ru = SnowballStemmer('russian')
stemmer_eng = SnowballStemmer('english')

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import cross_val_score, train_test_split
from lightgbm import LGBMClassifier
from scipy.sparse import csr_matrix,hstack

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

from sklearn.linear_model import LogisticRegression

from src.utils import *

# %%
df = pd.read_csv('data/posts_df.csv')
df, new_data = data_pretransform(df)
df['business'] = (df['class']=='business').astype(int)

# %% [markdown]
# ## Логистическая регрессия

# %%
model = LogisticRegression()

# %%
# %%time
## Проверка точности модели - кросс валидация и просмотр точности по классам
## Для моделей с tf-idf
target_cat = 'business'

data = df
# new_data == вектора tf_idf

all_prediction = pd.DataFrame()
from sklearn.model_selection import ShuffleSplit
ss = ShuffleSplit()
for tr, ts in ss.split(new_data, data[target_cat]):
    X_train, X_test, y_train,y_test = new_data.toarray()[tr], new_data.toarray()[ts], data[target_cat].iloc[tr], data[target_cat].iloc[ts]
    
    model.fit(X_train, y_train)
    prediction = model.predict_proba(X_test)
    prediction = pd.DataFrame(prediction)
    prediction['cat'] = y_test.values
    prediction['pred_cat'] = model.predict(X_test)
    prediction['index'] = ts


    all_prediction = pd.concat([prediction,all_prediction], axis = 0)
# all_prediction.to_csv('data/cross_val_result.csv', index = False)



from sklearn.metrics import f1_score, precision_score, recall_score
# all_prediction = pd.read_csv('cross_val_result.csv', index_col = 'index')

score = pd.DataFrame()
score['cat_id'] = data[target_cat].unique()
score['precision_score'] = score['cat_id'].apply(lambda x: precision_score(all_prediction['cat'], all_prediction['pred_cat'],labels = [x], average = 'micro'))
score['f1_score'] = score['cat_id'].apply(lambda x: f1_score(all_prediction['cat'], all_prediction['pred_cat'],labels = [x], average = 'micro'))
score['recall_score'] = score['cat_id'].apply(lambda x: recall_score(all_prediction['cat'], all_prediction['pred_cat'],labels = [x], average = 'micro'))
# Out:
# C:\Users\1\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\1\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\1\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\1\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\1\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\1\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\1\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Wall time: 1.95 s
# C:\Users\1\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\1\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\1\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
score
# Out:
#    cat_id  precision_score  f1_score  recall_score
# 0       1         0.943787  0.801004      0.695747
# 1       0         0.914522  0.949578      0.987430

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
true = encoder.fit_transform(all_prediction['cat'])
preds = encoder.transform(all_prediction['pred_cat'])
plot_confusion_matrix(true, preds, score['cat_id'].values)

# %% [markdown]
# ## Бустинг

# %%
model = LGBMClassifier(
                 n_estimators = 500,
                 learning_rate=0.1,
                 random_state = 2,
                 feature_fraction = 0.70,
                 num_leaves = 20,
                 max_bin=1000,
                 min_data_in_leaf = 500
)

# %%
# %%time
## Проверка точности модели - кросс валидация и просмотр точности по классам
## Для моделей с tf-idf
target_cat = 'business'

data = df
# new_data == вектора tf_idf

all_prediction = pd.DataFrame()
from sklearn.model_selection import ShuffleSplit
ss = ShuffleSplit()
for tr, ts in ss.split(new_data, data[target_cat]):
    X_train, X_test, y_train,y_test = new_data.toarray()[tr], new_data.toarray()[ts], data[target_cat].iloc[tr], data[target_cat].iloc[ts]
    
    model.fit(X_train, y_train)
    prediction = model.predict_proba(X_test)
    prediction = pd.DataFrame(prediction)
    prediction['cat'] = y_test.values
    prediction['pred_cat'] = model.predict(X_test)
    prediction['index'] = ts


    all_prediction = pd.concat([prediction,all_prediction], axis = 0)
# all_prediction.to_csv('data/cross_val_result.csv', index = False)



from sklearn.metrics import f1_score, precision_score, recall_score
# all_prediction = pd.read_csv('cross_val_result.csv', index_col = 'index')

score = pd.DataFrame()
score['cat_id'] = data[target_cat].unique()
score['precision_score'] = score['cat_id'].apply(lambda x: precision_score(all_prediction['cat'], all_prediction['pred_cat'],labels = [x], average = 'micro'))
score['f1_score'] = score['cat_id'].apply(lambda x: f1_score(all_prediction['cat'], all_prediction['pred_cat'],labels = [x], average = 'micro'))
score['recall_score'] = score['cat_id'].apply(lambda x: recall_score(all_prediction['cat'], all_prediction['pred_cat'],labels = [x], average = 'micro'))
# Out:
# Wall time: 3.23 s

# %%
score
# Out:
#    cat_id  precision_score  f1_score  recall_score
# 0       1         0.531073  0.173112      0.103410
# 1       0         0.783417  0.867825      0.972616

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
true = encoder.fit_transform(all_prediction['cat'])
preds = encoder.transform(all_prediction['pred_cat'])
plot_confusion_matrix(true, preds, score['cat_id'].values)

# %% [markdown]
# ## Рандомный лес

# %%
model = RandomForestClassifier()

# %%
# %%time
## Проверка точности модели - кросс валидация и просмотр точности по классам
## Для моделей с tf-idf
target_cat = 'business'

data = df
# new_data == вектора tf_idf

all_prediction = pd.DataFrame()
from sklearn.model_selection import ShuffleSplit
ss = ShuffleSplit()
for tr, ts in ss.split(new_data, data[target_cat]):
    X_train, X_test, y_train,y_test = new_data.toarray()[tr], new_data.toarray()[ts], data[target_cat].iloc[tr], data[target_cat].iloc[ts]
    
    model.fit(X_train, y_train)
    prediction = model.predict_proba(X_test)
    prediction = pd.DataFrame(prediction)
    prediction['cat'] = y_test.values
    prediction['pred_cat'] = model.predict(X_test)
    prediction['index'] = ts


    all_prediction = pd.concat([prediction,all_prediction], axis = 0)
# all_prediction.to_csv('data/cross_val_result.csv', index = False)



from sklearn.metrics import f1_score, precision_score, recall_score
# all_prediction = pd.read_csv('cross_val_result.csv', index_col = 'index')

score = pd.DataFrame()
score['cat_id'] = data[target_cat].unique()
score['precision_score'] = score['cat_id'].apply(lambda x: precision_score(all_prediction['cat'], all_prediction['pred_cat'],labels = [x], average = 'micro'))
score['f1_score'] = score['cat_id'].apply(lambda x: f1_score(all_prediction['cat'], all_prediction['pred_cat'],labels = [x], average = 'micro'))
score['recall_score'] = score['cat_id'].apply(lambda x: recall_score(all_prediction['cat'], all_prediction['pred_cat'],labels = [x], average = 'micro'))
# Out:
# Wall time: 3.46 s

# %%
score
# Out:
#    cat_id  precision_score  f1_score  recall_score
# 0       1         0.902439  0.786250      0.696567
# 1       0         0.915510  0.945541      0.977609

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
true = encoder.fit_transform(all_prediction['cat'])
preds = encoder.transform(all_prediction['pred_cat'])
plot_confusion_matrix(true, preds, score['cat_id'].values)

# %% [markdown]
# ## Нейронка

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_csv('data/posts_df.csv')
df, new_data = data_pretransform(df, 'word2vec')
df['business'] = (df['class']=='business').astype(int)

# %%
maxlen = 150
max_features = 4000
output_size = len(df[target_cat].unique())
if output_size==2:
    output_size = 1
def RNN(maxlen):
    inputs = Input(name='inputs',shape=[maxlen])
    layer = Embedding(max_features,50,input_length=maxlen)(inputs)
    layer = LSTM(64)(layer)
    layer = Dense(256,name='FC1')(layer)
    layer = Activation('relu')(layer)
    layer = Dropout(0.5)(layer)
    layer = Dense(output_size,name='out_layer')(layer)
    layer = Activation('sigmoid')(layer)
    model = Model(inputs=inputs,outputs=layer)
    return model

model = RNN(maxlen)
model.summary()
model.compile(loss='binary_crossentropy',optimizer=RMSprop(),metrics=['accuracy'])
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 150)]             0
# _________________________________________________________________
# embedding_6 (Embedding)      (None, 150, 50)           200000
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 64)                29440
# _________________________________________________________________
# FC1 (Dense)                  (None, 256)               16640
# _________________________________________________________________
# activation_10 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# out_layer (Dense)            (None, 1)                 257
# _________________________________________________________________
# activation_11 (Activation)   (None, 1)                 0
# =================================================================
# Total params: 246,337
# Trainable params: 246,337
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
## Проверка точности модели - кросс валидация и просмотр точности по классам
## Для нейросетевых моделей с word2vec
target_cat = 'business'

data = df
# new_data == вектора tf_idf

all_prediction = pd.DataFrame()
from sklearn.model_selection import ShuffleSplit
ss = ShuffleSplit()
for tr, ts in ss.split(new_data, data[target_cat]):#.toarray()
    X_train, X_test, y_train,y_test = new_data[tr], new_data[ts], data[target_cat].iloc[tr].values, data[target_cat].iloc[ts].values
    
    model.fit(X_train, y_train)
    prediction = model.predict(X_test) #predict_proba
    prediction = pd.DataFrame(prediction)
    prediction['cat'] = y_test
    prediction['pred_cat'] = model.predict(X_test).astype(int)
    prediction['index'] = ts


    all_prediction = pd.concat([prediction,all_prediction], axis = 0)
# all_prediction.to_csv('data/cross_val_result.csv', index = False)



from sklearn.metrics import f1_score, precision_score, recall_score
# all_prediction = pd.read_csv('cross_val_result.csv', index_col = 'index')

score = pd.DataFrame()
score['cat_id'] = data[target_cat].unique()
score['precision_score'] = score['cat_id'].apply(lambda x: precision_score(all_prediction['cat'], all_prediction['pred_cat'],labels = [x], average = 'micro'))
score['f1_score'] = score['cat_id'].apply(lambda x: f1_score(all_prediction['cat'], all_prediction['pred_cat'],labels = [x], average = 'micro'))
score['recall_score'] = score['cat_id'].apply(lambda x: recall_score(all_prediction['cat'], all_prediction['pred_cat'],labels = [x], average = 'micro'))
# Out:
# Train on 3539 samples
# 3539/3539 [==============================] - 5s 1ms/sample - loss: 0.5466 - accuracy: 0.7677
# Train on 3539 samples
# 3539/3539 [==============================] - 5s 1ms/sample - loss: 0.5444 - accuracy: 0.7694
# Train on 3539 samples
# 3539/3539 [==============================] - 5s 1ms/sample - loss: 0.5507 - accuracy: 0.7635
# Train on 3539 samples
# 3539/3539 [==============================] - 5s 1ms/sample - loss: 0.5451 - accuracy: 0.7677
# Train on 3539 samples
# 3539/3539 [==============================] - 5s 1ms/sample - loss: 0.5446 - accuracy: 0.7677
# Train on 3539 samples
# 3539/3539 [==============================] - 5s 1ms/sample - loss: 0.5534 - accuracy: 0.7626
# Train on 3539 samples
# 3539/3539 [==============================] - 5s 1ms/sample - loss: 0.5418 - accuracy: 0.7697
# Train on 3539 samples
# 3539/3539 [==============================] - 5s 1ms/sample - loss: 0.5516 - accuracy: 0.7641
# Train on 3539 samples
# 3539/3539 [==============================] - 5s 2ms/sample - loss: 0.5472 - accuracy: 0.7663
# Train on 3539 samples
# 3539/3539 [==============================] - 5s 1ms/sample - loss: 0.5514 - accuracy: 0.7615
# Wall time: 56.9 s
# C:\Users\1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
score
# Out:
#    cat_id  precision_score  f1_score  recall_score
# 0       1         0.000000  0.000000           0.0
# 1       0         0.766497  0.867816           1.0

# %%
all_prediction
# Out:
#        0    1  cat  pred_cat  index
# 0    1.0  0.0    0         0   1953
# 1    0.8  0.2    0         0   3105
# 2    1.0  0.0    0         0   3359
# 3    0.0  1.0    1         1   3664
# 4    1.0  0.0    0         0   2243
# ..   ...  ...  ...       ...    ...
# 389  1.0  0.0    0         0   1561
# 390  0.8  0.2    0         0   2858
# 391  0.2  0.8    1         1   3924
# 392  0.7  0.3    0         0    682
# 393  0.4  0.6    1         1    373
#
# [3940 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
true = encoder.fit_transform(all_prediction['cat'])
preds = encoder.transform(all_prediction['pred_cat'])
plot_confusion_matrix(true, preds, score['cat_id'].values)
